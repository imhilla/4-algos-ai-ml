# %% [markdown]
# # show_digit_data
# Draw the data in digit_data.txt.

# %%
import tkinter as tk
# !jupyter notebook --version
# !python3 --version
# Out:
# 7.0.6
# Python 3.12.0

# %%
from functools import partial

# Geometry constants.
NUM_COLS = 20
NUM_ROWS = 10
NUM_X_PIX = 6
NUM_Y_PIX = 8
PIX_SIZE = 2
MARGIN = 5
CELL_WID = NUM_X_PIX * PIX_SIZE
CELL_HGT = NUM_Y_PIX * PIX_SIZE
CANVAS_WID = NUM_COLS * CELL_WID + (NUM_COLS - 1) * MARGIN
CANVAS_HGT = NUM_ROWS * CELL_HGT + (NUM_ROWS - 1) * MARGIN
WINDOW_WID = CANVAS_WID + 2 * MARGIN
WINDOW_HGT = CANVAS_HGT + 2 * MARGIN

class App:
    # Create and manage the tkinter interface.
    def __init__(self):
        self.network = None

        # Build the UI.
        self.build_ui()

        # Display the window.
        self.window.focus_force()
        self.window.mainloop()

    def build_ui(self):
        # Make the main interface.
        self.window = tk.Tk()
        self.window.title('show_digit_data')
        self.window.protocol('WM_DELETE_WINDOW', self.kill_callback)
        self.window.geometry(f'{WINDOW_WID}x{WINDOW_HGT}')

        # Make the drawing canvas.
        self.canvas = tk.Canvas(self.window, bg='white',
            borderwidth=0, highlightthickness=0, relief=tk.SUNKEN,
            width=CANVAS_WID, height=CANVAS_HGT)
        self.canvas.pack(side=tk.LEFT, padx=MARGIN, pady=MARGIN)

        # Load data.
        with open('digit_data.txt', 'r') as f:
            lines = f.readlines()

        line_num = 0
        y = 0
        for row in range(NUM_ROWS):
            x = 0
            for col in range(NUM_COLS):
                i = row * NUM_COLS + col
                data = lines[i].split()[1]
                self.draw_digit(data, x, y)
                x += CELL_WID + MARGIN
            y += CELL_HGT + MARGIN

    def draw_digit(self, data, x0, y0):
        i = 0
        x = x0
        y = y0
        for letter in data:
            if letter == '1':
                self.canvas.create_rectangle(x, y, x + PIX_SIZE, y + PIX_SIZE, fill='black')
            i += 1
            x += PIX_SIZE
            if i % NUM_X_PIX == 0:
                x = x0
                y += PIX_SIZE

    def kill_callback(self):
        self.window.destroy()

# %%
App()
# Out:
# 1   HIToolbox                           0x00000001b1b145c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x00000001b1b14188 _ZN15MenuBarInstance14EnableAutoShowEv + 60
# 3   HIToolbox                           0x00000001b1a818bc _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1184
# 4   HIToolbox                           0x00000001b1b14004 _ZN15MenuBarInstance19SetFullScreenUIModeEjj + 180
# 5   AppKit                              0x00000001ab903d30 -[NSApplication _setPresentationOptions:instance:flags:] + 956
# 6   AppKit                              0x00000001ab79993c -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 404
# 7   CoreFoundation                      0x00000001a83b6560 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 148
# 8   CoreFoundation                      0x00000001a8454044 ___CFXRegistrationPost_block_invoke + 88
# 9   CoreFoundation                      0x00000001a8453f8c _CFXRegistrationPost + 440
# 10  CoreFoundation                      0x00000001a8387b64 _CFXNotificationPost + 708
# 11  Foundation                          0x00000001a927738c -[NSNotificationCenter postNotificationName:object:userInfo:] + 88
# 12  AppKit                              0x00000001ab9042b4 spacesNotificationHandler + 96
# 13  SkyLight                            0x00000001acff1214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 14  SkyLight                            0x00000001ad31d4d4 _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 228
# 15  SkyLight                            0x00000001ad31d3d0 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 28
# 16  libdispatch.dylib                   0x00000001a81589dc _dispatch_call_block_and_release + 32
# 17  libdispatch.dylib                   0x00000001a815a504 _dispatch_client_callout + 20
# 18  libdispatch.dylib                   0x00000001a8168d1c _dispatch_main_queue_drain + 928
# 19  libdispatch.dylib                   0x00000001a816896c _dispatch_main_queue_callback_4CF + 44
# 20  CoreFoundation                      0x00000001a8402d40 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 16
# 21  CoreFoundation                      0x00000001a83c07c0 __CFRunLoopRun + 2036
# 22  CoreFoundation                      0x00000001a83bf878 CFRunLoopRunSpecific + 612
# 23  libtcl8.6.dylib                     0x0000000117ab3d7c Tcl_WaitForEvent + 376
# 24  libtcl8.6.dylib                     0x0000000117a5f248 Tcl_DoOneEvent + 224
# 25  _tkinter.cpython-312-darwin.so      0x0000000107345dbc _tkinter_tkapp_mainloop + 336
# 26  python3.12                          0x0000000104b90a38 method_vectorcall_FASTCALL + 168
# 27  python3.12                          0x0000000104b80a54 PyObject_Vectorcall + 88
# 28  python3.12                          0x0000000104c9bca4 _PyEval_EvalFrameDefault + 54644
# 29  python3.12                          0x0000000104b8037c _PyObject_FastCallDictTstate + 324
# 30  python3.12                          0x0000000104c04058 slot_tp_init + 332
# 31  python3.12                          0x0000000104bfc354 type_call + 496
# 32  python3.12                          0x0000000104b7fed8 _PyObject_MakeTpCall + 316
# 33  python3.12                          0x0000000104c9bca4 _PyEval_EvalFrameDefault + 54644
# 34  python3.12                          0x0000000104c8d814 PyEval_EvalCode + 300
# 35  python3.12                          0x0000000104c8a374 builtin_exec + 1412
# 36  python3.12                          0x0000000104c9cf2c _PyEval_EvalFrameDefault + 59388
# 37  python3.12                          0x0000000104b9f910 gen_send_ex2 + 552
# 38  python3.12                          0x0000000104b9e79c gen_send_ex + 56
# 39  python3.12                          0x0000000104c9d474 _PyEval_EvalFrameDefault + 60740
# 40  python3.12                          0x0000000104b840b0 method_vectorcall + 188
# 41  python3.12                          0x0000000104b808ac _PyVectorcall_Call + 132
# 42  python3.12                          0x0000000104c9dbb0 _PyEval_EvalFrameDefault + 62592
# 43  python3.12                          0x0000000104b9f910 gen_send_ex2 + 552
# 44  _asyncio.cpython-312-darwin.so      0x0000000105c4f894 task_step_impl + 472
# 45  _asyncio.cpython-312-darwin.so      0x0000000105c50a50 task_step + 68
# 46  _asyncio.cpython-312-darwin.so      0x0000000105c5083c task_wakeup + 272
# 47  python3.12                          0x0000000104bdcc38 cfunction_vectorcall_O + 296
# 48  python3.12                          0x0000000104cbf9ac context_run + 352
# 49  python3.12                          0x0000000104bdcebc cfunction_vectorcall_FASTCALL_KEYWORDS + 144
# 50  python3.12                          0x0000000104c9dbb0 _PyEval_EvalFrameDefault + 62592
# 51  python3.12                          0x0000000104c8d814 PyEval_EvalCode + 300
# 52  python3.12                          0x0000000104c8a374 builtin_exec + 1412
# 53  python3.12                          0x0000000104bdcebc cfunction_vectorcall_FASTCALL_KEYWORDS + 144
# 54  python3.12                          0x0000000104b80a54 PyObject_Vectorcall + 88
# 55  python3.12                          0x0000000104c9bca4 _PyEval_EvalFrameDefault + 54644
# 56  python3.12                          0x0000000104d32a30 pymain_run_module + 292
# 57  python3.12                          0x0000000104d323c4 Py_RunMain + 2016
# 58  python3.12                          0x0000000104d332f4 pymain_main + 660
# 59  python3.12                          0x0000000104b1a4bc main + 56
# 60  dyld                                0x00000001a7fb7e50 start + 2544
# 1   HIToolbox                           0x00000001b1a9f90c _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 44
# 2   HIToolbox                           0x00000001b1b14fbc _ZN15MenuBarInstance15DisableAutoShowEv + 36
# 3   HIToolbox                           0x00000001b1b150b0 _ZN15MenuBarInstanceD2Ev + 128
# 4   HIToolbox                           0x00000001b1b14ee0 _ZN15MenuBarInstance7ReleaseEv + 56
# 5   AppKit                              0x00000001abca14dc -[NSHIPresentationInstance discard] + 228
# 6   AppKit                              0x00000001ac0608b4 -[_NSFullScreenSpace(PresentationInstance) discardPresentationInstance] + 32
# 7   AppKit                              0x00000001ac06090c -[_NSFullScreenSpace(PresentationInstance) activateFullScreenPresentationOptions] + 64
# 8   AppKit                              0x00000001abeba968 -[_NSExitFullScreenTransitionController _doSucceededToExitFullScreen] + 40
# 9   AppKit                              0x00000001abebb440 __63-[_NSExitFullScreenTransitionController _performExitFullScreen]_block_invoke + 236
# 10  libxpc.dylib                        0x00000001a805242c _xpc_connection_reply_callout + 124
# 11  libxpc.dylib                        0x00000001a805231c _xpc_connection_call_reply_async + 88
# 12  libdispatch.dylib                   0x00000001a815a584 _dispatch_client_callout3 + 20
# 13  libdispatch.dylib                   0x00000001a8178710 _dispatch_mach_msg_async_reply_invoke + 344
# 14  libdispatch.dylib                   0x00000001a8168c70 _dispatch_main_queue_drain + 756
# 15  libdispatch.dylib                   0x00000001a816896c _dispatch_main_queue_callback_4CF + 44
# 16  CoreFoundation                      0x00000001a8402d40 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 16
# 17  CoreFoundation                      0x00000001a83c07c0 __CFRunLoopRun + 2036
# 18  CoreFoundation                      0x00000001a83bf878 CFRunLoopRunSpecific + 612
# 19  HIToolbox                           0x00000001b1a9ffa0 RunCurrentEventLoopInMode + 292
# 20  HIToolbox                           0x00000001b1a9fc30 ReceiveNextEventCommon + 236
# 21  HIToolbox                           0x00000001b1a9fb2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 22  AppKit                              0x00000001ab64584c _DPSNextEvent + 632
# 23  AppKit                              0x00000001ab6449dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 24  libtk8.6.dylib                      0x000000011146610c TkMacOSXEventsCheckProc + 448
# 25  libtcl8.6.dylib                     0x0000000117a5f2a8 Tcl_DoOneEvent + 320
# 26  _tkinter.cpython-312-darwin.so      0x0000000107345dbc _tkinter_tkapp_mainloop + 336
# 27  python3.12                          0x0000000104b90a38 method_vectorcall_FASTCALL + 168
# 28  python3.12                          0x0000000104b80a54 PyObject_Vectorcall + 88
# 29  python3.12                          0x0000000104c9bca4 _PyEval_EvalFrameDefault + 54644
# 30  python3.12                          0x0000000104b8037c _PyObject_FastCallDictTstate + 324
# 31  python3.12                          0x0000000104c04058 slot_tp_init + 332
# 32  python3.12                          0x0000000104bfc354 type_call + 496
# 33  python3.12                          0x0000000104b7fed8 _PyObject_MakeTpCall + 316
# 34  python3.12                          0x0000000104c9bca4 _PyEval_EvalFrameDefault + 54644
# 35  python3.12                          0x0000000104c8d814 PyEval_EvalCode + 300
# 36  python3.12                          0x0000000104c8a374 builtin_exec + 1412
# 37  python3.12                          0x0000000104c9cf2c _PyEval_EvalFrameDefault + 59388
# 38  python3.12                          0x0000000104b9f910 gen_send_ex2 + 552
# 39  python3.12                          0x0000000104b9e79c gen_send_ex + 56
# 40  python3.12                          0x0000000104c9d474 _PyEval_EvalFrameDefault + 60740
# 41  python3.12                          0x0000000104b840b0 method_vectorcall + 188
# 42  python3.12                          0x0000000104b808ac _PyVectorcall_Call + 132
# 43  python3.12                          0x0000000104c9dbb0 _PyEval_EvalFrameDefault + 62592
# 44  python3.12                          0x0000000104b9f910 gen_send_ex2 + 552
# 45  _asyncio.cpython-312-darwin.so      0x0000000105c4f894 task_step_impl + 472
# 46  _asyncio.cpython-312-darwin.so      0x0000000105c50a50 task_step + 68
# 47  _asyncio.cpython-312-darwin.so      0x0000000105c5083c task_wakeup + 272
# 48  python3.12                          0x0000000104bdcc38 cfunction_vectorcall_O + 296
# 49  python3.12                          0x0000000104cbf9ac context_run + 352
# 50  python3.12                          0x0000000104bdcebc cfunction_vectorcall_FASTCALL_KEYWORDS + 144
# 51  python3.12                          0x0000000104c9dbb0 _PyEval_EvalFrameDefault + 62592
# 52  python3.12                          0x0000000104c8d814 PyEval_EvalCode + 300
# 53  python3.12                          0x0000000104c8a374 builtin_exec + 1412
# 54  python3.12                          0x0000000104bdcebc cfunction_vectorcall_FASTCALL_KEYWORDS + 144
# 55  python3.12                          0x0000000104b80a54 PyObject_Vectorcall + 88
# 56  python3.12                          0x0000000104c9bca4 _PyEval_EvalFrameDefault + 54644
# 57  python3.12                          0x0000000104d32a30 pymain_run_module + 292
# 58  python3.12                          0x0000000104d323c4 Py_RunMain + 2016
# 59  python3.12                          0x0000000104d332f4 pymain_main + 660
# 60  python3.12                          0x0000000104b1a4bc main + 56
# 61  dyld                                0x00000001a7fb7e50 start + 2544
